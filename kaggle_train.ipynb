# %% [markdown]
# # LNN Enemy AI - Kaggle PPO Trainer
# Upload the `lnn_kaggle.zip` as a Kaggle Dataset, or just drag and drop the unzipped folder directly into the right-hand `/kaggle/working/` directory.

# %%
# !pip install torch numpy transformers useful-moonshine

# %%
# Make sure we are in the correct directory if uploaded via dataset
import os
# os.chdir("/kaggle/working/lnn_kaggle")

# Run the massive 21.4M parameter Dual-Brain Self-Play Trainer
# !python trainer_rl.py
